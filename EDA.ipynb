# %% [markdown]
# ### import libraries

# %%
import pandas as pd
import numpy as nb
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## load dataset

# %%
df = pd.read_csv('datasets/raw/train_dataset.csv')

# %% [markdown]
# ### Overview

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1900 entries, 0 to 1899
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          1900 non-null   object
#  1   Age                             1900 non-null   int64
#  2   Height                          1900 non-null   float64
#  3   Weight                          1900 non-null   float64
#  4   family_history_with_overweight  1900 non-null   object
#  5   FAVC                            1900 non-null   object
#  6   FCVC                            1888 non-null   float64
#  7   NCP                             1900 non-null   float64
#  8   CAEC                            1900 non-null   object
#  9   SMOKE                           1900 non-null   object
#  10  CH2O                            1900 non-null   float64
#  11  SCC                             1900 non-null   object
#  12  FAF                             1900 non-null   float64
#  13  TUE                             1900 non-null   float64
#  14  CALC                            1872 non-null   object
#  15  MTRANS                          1900 non-null   object
#  16  NObeyesdad                      1900 non-null   object
# dtypes: float64(7), int64(1), object(9)
# memory usage: 252.5+ KB

# %%
df.head()
# Out:
#    Gender  Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female   18    1.82  142.10                            yes  yes  3.00
# 1    Male   32    1.84   98.26                            yes  yes  2.33
# 2    Male   24    1.76  117.33                            yes  yes  1.54
# 3  Female   26    1.62  110.68                            yes  yes  3.00
# 4    Male   32    1.78  121.20                            yes  yes  2.76
#
#     NCP       CAEC SMOKE  CH2O SCC   FAF    TUE       CALC  \
# 0  3.00  Sometimes    no  2.71  no  2.00  0.814  Sometimes
# 1  1.82  Sometimes    no  2.56  no  1.33  0.481  Sometimes
# 2  3.00  Sometimes    no  2.00  no  1.63  0.631        NaN
# 3  3.00  Sometimes    no  2.69  no  0.00  0.425        NaN
# 4  3.00  Sometimes    no  2.16  no  0.43  0.716        NaN
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation     Obesity_Type_III
# 1             Automobile  Overweight_Level_II
# 2  Public_Transportation      Obesity_Type_II
# 3  Public_Transportation     Obesity_Type_III
# 4             Automobile      Obesity_Type_II

# %% [markdown]
# ## missing values

# %%
df.isnull().sum()
# Out:
# Gender                             0
# Age                                0
# Height                             0
# Weight                             0
# family_history_with_overweight     0
# FAVC                               0
# FCVC                              12
# NCP                                0
# CAEC                               0
# SMOKE                              0
# CH2O                               0
# SCC                                0
# FAF                                0
# TUE                                0
# CALC                              28
# MTRANS                             0
# NObeyesdad                         0
# dtype: int64

# %% [markdown]
# ## duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(22)

# %%
df=df.drop_duplicates()

# %% [markdown]
# ### Statistics

# %%
df.describe(include='all').transpose()
# Out:
#                                  count unique                    top  freq  \
# Gender                            1878      2                   Male   943
# Age                             1878.0    NaN                    NaN   NaN
# Height                          1878.0    NaN                    NaN   NaN
# Weight                          1878.0    NaN                    NaN   NaN
# family_history_with_overweight    1878      2                    yes  1546
# FAVC                              1878      2                    yes  1669
# FCVC                            1866.0    NaN                    NaN   NaN
# NCP                             1878.0    NaN                    NaN   NaN
# CAEC                              1878      4              Sometimes  1585
# SMOKE                             1878      2                     no  1838
# CH2O                            1878.0    NaN                    NaN   NaN
# SCC                               1878      2                     no  1789
# FAF                             1878.0    NaN                    NaN   NaN
# TUE                             1878.0    NaN                    NaN   NaN
# CALC                              1850      4              Sometimes  1214
# MTRANS                            1878      5  Public_Transportation  1412
# NObeyesdad                        1878      7         Obesity_Type_I   322
#
#                                      mean       std   min     25%     50%  \
# Gender                                NaN       NaN   NaN     NaN     NaN
# Age                             24.323749  6.311027  14.0    20.0    23.0
# Height                           1.702433  0.092934  1.45    1.63     1.7
# Weight                          86.791901  26.15612  39.0    66.0  83.135
# family_history_with_overweight        NaN       NaN   NaN     NaN     NaN
# FAVC                                  NaN       NaN   NaN     NaN     NaN
# FCVC                             2.419512  0.537197   1.0     2.0    2.39
# NCP                              2.699489  0.766198   1.0  2.6925     3.0
# CAEC                                  NaN       NaN   NaN     NaN     NaN
# SMOKE                                 NaN       NaN   NaN     NaN     NaN
# CH2O                              2.01229  0.606663   1.0    1.61     2.0
# SCC                                   NaN       NaN   NaN     NaN     NaN
# FAF                               1.00722  0.856061   0.0  0.1125     1.0
# TUE                              0.669223  0.607728   0.0     0.0  0.6425
# CALC                                  NaN       NaN   NaN     NaN     NaN
# MTRANS                                NaN       NaN   NaN     NaN     NaN
# NObeyesdad                            NaN       NaN   NaN     NaN     NaN
#
#                                      75%    max
# Gender                               NaN    NaN
# Age                                 26.0   61.0
# Height                              1.77   1.98
# Weight                          107.9875  173.0
# family_history_with_overweight       NaN    NaN
# FAVC                                 NaN    NaN
# FCVC                                 3.0    3.0
# NCP                                  3.0    4.0
# CAEC                                 NaN    NaN
# SMOKE                                NaN    NaN
# CH2O                                2.47    3.0
# SCC                                  NaN    NaN
# FAF                                 1.67    3.0
# TUE                                  1.0    2.0
# CALC                                 NaN    NaN
# MTRANS                               NaN    NaN
# NObeyesdad                           NaN    NaN

# %% [markdown]
# ### count plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df,x=i)
    plt.show()

# %% [markdown]
# ### boxplot

# %%
for i in df.select_dtypes(include="number").columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %% [markdown]
# ###  corrrelation heatmap

# %%
h=df.select_dtypes(include="number").corr() #to show correlation between numeric data
sns.heatmap(h,annot=True)
# Out:
# <Axes: >

# %%
df.NObeyesdad.value_counts() #imbalanced classes
# Out:
# NObeyesdad
# Obesity_Type_I         322
# Obesity_Type_III       296
# Obesity_Type_II        259
# Overweight_Level_II    256
# Normal_Weight          251
# Overweight_Level_I     251
# Insufficient_Weight    243
# Name: count, dtype: int64
